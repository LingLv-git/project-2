# %%
import time

from bs4 import BeautifulSoup
import pandas as pd
import requests
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager


# %load_ext nb_black

# %%
executable_path = {"executable_path": ChromeDriverManager().install()}
browser = Browser("chrome", **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 93.0.4577
# Get LATEST driver version for 93.0.4577
# Get LATEST driver version for 93.0.4577
# Trying to download new driver from https://chromedriver.storage.googleapis.com/93.0.4577.63/chromedriver_mac64.zip
# Driver has been saved in cache [/Volumes/UsersHome/linglv/.wdm/drivers/chromedriver/mac64/93.0.4577.63]

# %%
url = "https://www.yelp.com/search?find_desc=Restaurants&find_loc=Georgia%20Tech%2C%20Atlanta%2C%20GA&ns=1&l=g%3A-84.41276550292969%2C33.76816006007425%2C-84.38718795776367%2C33.78956253387451"
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, "html.parser")

# %%
result = []
while True:
    eles = soup.find_all(
        "div", class_=["container__09f24__sxa9-", "hoverable__09f24__3HkY2"]
    )
    for ele in eles:
        name = ele.find_all("div", class_="businessName__09f24__3Ml2X")[0].text
        reviewer = None
        price = None
        restauran_type = None
        star = None

        try:
            reviewer = ele.find_all(
                "span", class_="reviewCount__09f24__3GsGY css-e81eai"
            )[0].text
        except:
            pass

        try:
            price = ele.find_all("span", class_="priceRange__09f24__2GspP css-e81eai")[
                0
            ].text
        except:
            pass

        try:
            types = ele.find_all("p", class_=["text__09f24__2NHRu", "css-1hx6l2b"])
            l = len(types)
            for i in l:
                restauran_type.append(types[i])
        except:
            pass

        try:
            star = ele.find_all("div", class_="i-stars__09f24___sZu0")[0]["aria-label"]
        except:
            pass
        result.append(
            {
                "name": name,
                "reviewer": reviewer,
                "price": price,
                "restauran_type": restauran_type,
                "star": star,
            }
        )
    try:
        time.sleep(1)
        browser.find_by_css(
            ".next-link.navigation-button__09f24__1EzzD.css-166la90"
        ).click()
    except:
        print("end of the list")
        break
result
# Out:
# end of the list
# [{'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'},
#  {'name': 'Moe’s Southwest Grill',
#   'reviewer': None,
#   'price': None,
#   'restauran_type': None,
#   'star': None},
#  {'name': 'QDOBA Mexican Eats',
#   'reviewer': '5',
#   'price': None,
#   'restauran_type': None,
#   'star': '3 star rating'},
#  {'name': '1.\xa0There on Fifth',
#   'reviewer': '39',
#   'price': None,
#   'restauran_type': None,
#   'star': '5 star rating'},
#  {'name': '2.\xa0Rock Steady - Atlanta',
#   'reviewer': '197',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '3.\xa0The Optimist',
#   'reviewer': '1764',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '4.\xa0Food Terminal - Atlanta',
#   'reviewer': '173',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '5.\xa0Forza Storico',
#   'reviewer': '222',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '6.\xa0Choong Man Chicken - Georgia Tech',
#   'reviewer': '51',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '7.\xa0Pijiu Belly',
#   'reviewer': '442',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '8.\xa0Velvet Taco',
#   'reviewer': '52',
#   'price': None,
#   'restauran_type': None,
#   'star': '4.5 star rating'},
#  {'name': '9.\xa0JCT Kitchen & Bar',
#   'reviewer': '1795',
#   'price': None,
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': '10.\xa0Le Fat',
#   'reviewer': '402',
#   'price': '$$',
#   'restauran_type': None,
#   'star': '4 star rating'},
#  {'name': 'Firehouse Subs',
#   'reviewer': '63',
#   'price': None,
#   'restauran_type': None,
#   'star': '3.5 star rating'}]

# %%
result_df = pd.DataFrame(result)
result_df.to_csv("yelp_data.csv")
result_df.shape
# Out:
# (377, 5)

# %%
result_df.drop_duplicates(subset=["name"], inplace=True)
result_df["star"] = result_df["star"].str.replace(r"[^\d.]+", "")
result_df.shape
# Out:
# <ipython-input-10-bec8177e230b>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   result_df["star"] = result_df["star"].str.replace(r"[^\d.]+", "")
# (13, 5)
