# %%
import pandas as pd

# %%
# File to Load (Remember to Change These)
csv_file = "project 2.csv"

# Read Purchasing File and store into Pandas data frame
df = pd.read_csv(csv_file)
df.head()
# Out:
#                                          query    query_p1      query_p2  \
# 0  restaurant, North Ave NW, Atlanta, GA 30332  restaurant  North Ave NW
# 1  restaurant, North Ave NW, Atlanta, GA 30332  restaurant  North Ave NW
# 2  restaurant, North Ave NW, Atlanta, GA 30332  restaurant  North Ave NW
# 3  restaurant, North Ave NW, Atlanta, GA 30332  restaurant  North Ave NW
# 4  restaurant, North Ave NW, Atlanta, GA 30332  restaurant  North Ave NW
#
#   query_p3  query_p4                      name  \
# 0  Atlanta  GA 30332       endive Publik house
# 1  Atlanta  GA 30332                 MattChews
# 2  Atlanta  GA 30332               Ferst Place
# 3  Atlanta  GA 30332            Babette's Cafe
# 4  Atlanta  GA 30332  Gio’s Chicken Amalfitano
#
#                                     site                 type  \
# 0               http://endivepublik.com/  American restaurant
# 1                  http://mattchews.com/           Restaurant
# ...

# %%
new_df=df[['name', 'type', 'rating', 'reviews', 'range']].copy()
new_df.head()
# Out:
#                        name                 type  rating  reviews range
# 0       endive Publik house  American restaurant     4.9    199.0    $$
# 1                 MattChews           Restaurant     4.9     72.0    $$
# 2               Ferst Place           Restaurant     4.6     11.0   NaN
# 3            Babette's Cafe           Restaurant     4.8    383.0   $$$
# 4  Gio’s Chicken Amalfitano   Italian restaurant     4.5    848.0    $$
